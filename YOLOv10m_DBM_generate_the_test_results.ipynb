# %% [markdown]
# <a href="https://colab.research.google.com/github/N786h/YOLO-DBN/blob/main/YOLOv10m_DBM_generate_the_test_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Generate the test results with the already trained model by us

# %% [markdown]
# ####Install the modified Ultralytics library from our GitHub repository.

# %%
# !pip install git+https://github.com/N786h/YOLO-DBN.git
# Out:
# ...
#   Cloning https://github.com/N786h/YOLO-DBN.git to /tmp/pip-req-build-3xqrjm63
#   Running command git clone --filter=blob:none --quiet https://github.com/N786h/YOLO-DBN.git /tmp/pip-req-build-3xqrjm63
#   Resolved https://github.com/N786h/YOLO-DBN.git to commit cb31e185700ec6cbe8205589b765a9f4104a67f3
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for ultralytics: filename=ultralytics-8.4.14-py3-none-any.whl size=1005600 sha256=ac7fa0d1d415375d291d24bebce8d98c9c24919f7719d122af74251e58664dbc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fx6cuuly/wheels/56/48/40/018fca6b9d5217494eae75c7da128cc3278e0b47cd881a3511
# Successfully built ultralytics
# ...

# %% [markdown]
# ####Download the preprocessed and augmented publically available mulberry leaf disease dataset from Roboflow.

# %%
# !pip install roboflow

from google.colab import userdata
from roboflow import Roboflow
# Access the secret securely
api_key = userdata.get('ROBOFLOW_API_KEY')
rf = Roboflow(api_key=api_key)
project = rf.workspace("village").project("mulberry-nit0r")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.9/276.9 kB 9.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 17.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 45.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 68.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Mulberry-2 in yolov11:: 100%|██████████| 9019/9019 [00:01<00:00, 4883.00it/s]

# %% [markdown]
# ###Download the model

# %%
# Download the actual raw binary file from GitHub
# !wget -q -O best.pt https://github.com/N786h/YOLO-DBN/raw/main/models/best.pt
print("Model weights downloaded successfully.")
# Out:
# Model weights downloaded successfully.

# %% [markdown]
# ####Generate the test results

# %%
# Run validation with the corrected best.pt
# !yolo task=detect mode=val model=/content/best.pt data=/content/Mulberry-2/data.yaml split=test
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.4.14 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv10m-DAN summary: 443 layers, 21,531,673 parameters, 0 gradients, 95.9 GFLOPs
# ...
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1682.1±471.5 MB/s, size: 51.9 KB)
# val: Scanning /content/Mulberry-2/test/labels... 107 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 107/107 921.0it/s 0.1s
# val: New cache created: /content/Mulberry-2/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.2it/s 5.6s
#                    all        107        107      0.995      0.971      0.992      0.967
# ...
